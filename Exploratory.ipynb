# %% [markdown]
# # Import Libraries and Datasets

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from src.data_viz import EDA

# %%
# Define paths for each dataset

path = {
    "demographics" : "Data/Telco_customer_churn_demographics.xlsx",
    "location" : "Data/Telco_customer_churn_location.xlsx",
    "population" : "Data/Telco_customer_churn_population.xlsx",
    "services" : "Data/Telco_customer_churn_services.xlsx",
    "status" : "Data/Telco_customer_churn_status.xlsx",
    "churn" : "Data/Telco_customer_churn.xlsx"
}

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Demographics info

# %%
demographics_eda = EDA(path['demographics'])

demographics_eda.df.head()
# Out:
#   Customer ID  Count  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV      1    Male   78       No            Yes      No         No
# 1  7495-OOKFY      1  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY      1    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ      1  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ      1  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents
# 0                     0
# 1                     1
# 2                     3
# 3                     1
# 4                     1

# %%
# Basic Information

demographics_eda.basic_info()
# Out:
# Shape of the dataset: (7043, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Customer ID           7043 non-null   object
#  1   Count                 7043 non-null   int64
#  2   Gender                7043 non-null   object
#  3   Age                   7043 non-null   int64
#  4   Under 30              7043 non-null   object
#  5   Senior Citizen        7043 non-null   object
#  6   Married               7043 non-null   object
#  7   Dependents            7043 non-null   object
#  8   Number of Dependents  7043 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 495.3+ KB
#
# Data types and non-null counts:
#  None
#
# Summary statistics:
#          Count          Age  Number of Dependents
# count  7043.0  7043.000000           7043.000000
# mean      1.0    46.509726              0.468692
# std       0.0    16.750352              0.962802
# min       1.0    19.000000              0.000000
# 25%       1.0    32.000000              0.000000
# 50%       1.0    46.000000              0.000000
# 75%       1.0    60.000000              0.000000
# max       1.0    80.000000              9.000000

# %%
# Extract and Access Customer ID column if any

demographics_eda.extract_customer_id()

if demographics_eda.customer_id is not None:
    print(demographics_eda.customer_id.head())
# Out:
# Customer ID column 'Customer ID' extracted and removed from the DataFrame.
# 0    8779-QRDMV
# 1    7495-OOKFY
# 2    1658-BYGOY
# 3    4598-XLKNJ
# 4    4846-WHAFZ
# Name: Customer ID, dtype: object

# %%
# Check for duplicate values

demographics_eda.check_duplicate_values()
# Out:
# Duplicate rows: 0
#
# Nothing to remove :)

# %%
# Check for missing values

demographics_eda.check_missing_values()
# Out:
# Missing values:
#  Customer ID             0
# Count                   0
# Gender                  0
# Age                     0
# Under 30                0
# Senior Citizen          0
# Married                 0
# Dependents              0
# Number of Dependents    0
# dtype: int64

# %%
# Categorical Features Analysis

demographics_eda.categorical_analysis()

# %%
# Numerical Features Analysis

demographics_eda.numerical_analysis()

# %%
# Global Analysis

demographics_eda.pairplot_numerical()

# %%
# Crossbar tabulation to see relationship between categorical features

demographics_eda.crosstab_categorical()
# Out:
# Crosstabulation between Gender and Under 30:
#  Under 30    No  Yes
# Gender
# Female    2790  698
# Male      2852  703
#
# Crosstabulation between Gender and Senior Citizen:
#  Senior Citizen    No  Yes
# Gender
# Female          2920  568
# Male            2981  574
#
# Crosstabulation between Gender and Married:
#  Married    No   Yes
# Gender
# Female   1800  1688
# Male     1841  1714
#
# Crosstabulation between Gender and Dependents:
#  Dependents    No  Yes
# Gender
# Female      2690  798
# Male        2726  829
#
# Crosstabulation between Under 30 and Gender:
#  Gender    Female  Male
# Under 30
# No          2790  2852
# Yes          698   703
#
# Crosstabulation between Under 30 and Senior Citizen:
#  Senior Citizen    No   Yes
# Under 30
# No              4500  1142
# Yes             1401     0
#
# Crosstabulation between Under 30 and Married:
#  Married     No   Yes
# Under 30
# No        2938  2704
# Yes        703   698
#
# Crosstabulation between Under 30 and Dependents:
#  Dependents    No   Yes
# Under 30
# No          4388  1254
# Yes         1028   373
#
# Crosstabulation between Senior Citizen and Gender:
#  Gender          Female  Male
# Senior Citizen
# No                2920  2981
# Yes                568   574
#
# Crosstabulation between Senior Citizen and Under 30:
#  Under 30          No   Yes
# Senior Citizen
# No              4500  1401
# Yes             1142     0
#
# Crosstabulation between Senior Citizen and Married:
#  Married           No   Yes
# Senior Citizen
# No              3072  2829
# Yes              569   573
#
# Crosstabulation between Senior Citizen and Dependents:
#  Dependents        No   Yes
# Senior Citizen
# No              4347  1554
# Yes             1069    73
#
# Crosstabulation between Married and Gender:
#  Gender   Female  Male
# Married
# No         1800  1841
# Yes        1688  1714
#
# Crosstabulation between Married and Under 30:
#  Under 30    No  Yes
# Married
# No        2938  703
# Yes       2704  698
#
# Crosstabulation between Married and Senior Citizen:
#  Senior Citizen    No  Yes
# Married
# No              3072  569
# Yes             2829  573
#
# Crosstabulation between Married and Dependents:
#  Dependents    No   Yes
# Married
# No          3339   302
# Yes         2077  1325
#
# Crosstabulation between Dependents and Gender:
#  Gender      Female  Male
# Dependents
# No            2690  2726
# Yes            798   829
#
# Crosstabulation between Dependents and Under 30:
#  Under 30      No   Yes
# Dependents
# No          4388  1028
# Yes         1254   373
#
# Crosstabulation between Dependents and Senior Citizen:
#  Senior Citizen    No   Yes
# Dependents
# No              4347  1069
# Yes             1554    73
#
# Crosstabulation between Dependents and Married:
#  Married       No   Yes
# Dependents
# No          3339  2077
# Yes          302  1325
