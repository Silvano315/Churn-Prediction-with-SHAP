# %% [markdown]
# # Import Libraries and Datasets

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from src.data_viz import EDA

# %%
# Define paths for each dataset

path = {
    "demographics" : "Data/Telco_customer_churn_demographics.xlsx",
    "location" : "Data/Telco_customer_churn_location.xlsx",
    "population" : "Data/Telco_customer_churn_population.xlsx",
    "services" : "Data/Telco_customer_churn_services.xlsx",
    "status" : "Data/Telco_customer_churn_status.xlsx",
    "churn" : "Data/Telco_customer_churn.xlsx"
}

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Demographics info

# %%
demographics_eda = EDA(path['demographics'])

demographics_eda.df.head()
# Out:
#   Customer ID  Count  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV      1    Male   78       No            Yes      No         No
# 1  7495-OOKFY      1  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY      1    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ      1  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ      1  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents
# 0                     0
# 1                     1
# 2                     3
# 3                     1
# 4                     1

# %%
# Basic Information

demographics_eda.basic_info()
# Out:
# Shape of the dataset: (7043, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Customer ID           7043 non-null   object
#  1   Count                 7043 non-null   int64
#  2   Gender                7043 non-null   object
#  3   Age                   7043 non-null   int64
#  4   Under 30              7043 non-null   object
#  5   Senior Citizen        7043 non-null   object
#  6   Married               7043 non-null   object
#  7   Dependents            7043 non-null   object
#  8   Number of Dependents  7043 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 495.3+ KB
#
# Data types and non-null counts:
#  None
#
# Summary statistics:
#          Count          Age  Number of Dependents
# count  7043.0  7043.000000           7043.000000
# mean      1.0    46.509726              0.468692
# ...

# %%
# Extract and Access Customer ID column if any

demographics_eda.extract_customer_id()

if demographics_eda.customer_id is not None:
    print(demographics_eda.customer_id.head())
# Out:
# Customer ID column 'Customer ID' extracted and removed from the DataFrame.
# 0    8779-QRDMV
# 1    7495-OOKFY
# 2    1658-BYGOY
# 3    4598-XLKNJ
# 4    4846-WHAFZ
# Name: Customer ID, dtype: object

# %%
# Check for duplicate values

demographics_eda.check_duplicate_values()
# Out:
# Duplicate rows: 0
#
# Nothing to remove :)

# %%
# Check for missing values

demographics_eda.check_missing_values()
# Out:
# Missing values:
#  Customer ID             0
# Count                   0
# Gender                  0
# Age                     0
# Under 30                0
# Senior Citizen          0
# Married                 0
# Dependents              0
# Number of Dependents    0
# dtype: int64

# %%
# Categorical Features Analysis

demographics_eda.categorical_analysis()

# %%
# Numerical Features Analysis

demographics_eda.numerical_analysis()

# %%
# Global Analysis

demographics_eda.pairplot_numerical()

# %%
# Crossbar tabulation to see relationship between categorical features

demographics_eda.crosstab_categorical_plot()

# %%
# Correlation Matrix 

demographics_eda.correlation_matrix_heatmap()

# %% [markdown]
# ## Location Info

# %%
location_eda = EDA(path['location'])

location_eda.df.head()
# Out:
#   Location ID Customer ID  Count        Country       State         City  \
# 0  OXCZEW7397  8779-QRDMV      1  United States  California  Los Angeles
# 1  FCCECI8494  7495-OOKFY      1  United States  California  Los Angeles
# 2  HEHUQY7254  1658-BYGOY      1  United States  California  Los Angeles
# 3  WIUHRF2613  4598-XLKNJ      1  United States  California    Inglewood
# 4  CFEZBF4415  4846-WHAFZ      1  United States  California     Whittier
#
#    Zip Code                Lat Long   Latitude   Longitude
# 0     90022   34.02381, -118.156582  34.023810 -118.156582
# 1     90063  34.044271, -118.185237  34.044271 -118.185237
# 2     90065  34.108833, -118.229715  34.108833 -118.229715
# 3     90303  33.936291, -118.332639  33.936291 -118.332639
# 4     90602  33.972119, -118.020188  33.972119 -118.020188

# %%
# Basic Information

location_eda.basic_info()
# Out:
# Shape of the dataset: (7043, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location ID  7043 non-null   object
#  1   Customer ID  7043 non-null   object
#  2   Count        7043 non-null   int64
#  3   Country      7043 non-null   object
#  4   State        7043 non-null   object
#  5   City         7043 non-null   object
#  6   Zip Code     7043 non-null   int64
#  7   Lat Long     7043 non-null   object
#  8   Latitude     7043 non-null   float64
#  9   Longitude    7043 non-null   float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 550.4+ KB
#
# Data types and non-null counts:
#  None
#
# Summary statistics:
#          Count      Zip Code     Latitude    Longitude
# count  7043.0   7043.000000  7043.000000  7043.000000
# mean      1.0  93486.071134    36.197455  -119.756684
# ...

# %%
# Check for duplicate values

location_eda.check_duplicate_values()
# Out:
# Duplicate rows: 0
#
# Nothing to remove :)

# %%
# Check for missing values

location_eda.check_missing_values()
# Out:
# Missing values:
#  Location ID    0
# Customer ID    0
# Count          0
# Country        0
# State          0
# City           0
# Zip Code       0
# Lat Long       0
# Latitude       0
# Longitude      0
# dtype: int64

# %%
# Extract and Access ID column if any

location_eda.extract_customer_id()

if location_eda.customer_id is not None:
    print(location_eda.customer_id.head())
# Out:
# Customer ID column '['Location ID', 'Customer ID']' extracted and removed from the DataFrame.
#   Location ID Customer ID
# 0  OXCZEW7397  8779-QRDMV
# 1  FCCECI8494  7495-OOKFY
# 2  HEHUQY7254  1658-BYGOY
# 3  WIUHRF2613  4598-XLKNJ
# 4  CFEZBF4415  4846-WHAFZ

# %%
# Verify if Latitude and Longitude corresponds to Lat Log (round 4 digits)

lat_long_split = location_eda.df['Lat Long'].str.split(', ', expand=True).astype(float)

lat_long_split = lat_long_split.round(4)
latitude_rounded = location_eda.df['Latitude'].round(4)
longitude_rounded = location_eda.df['Longitude'].round(4)

latitude_match = latitude_rounded == lat_long_split[0]
longitude_match = longitude_rounded == lat_long_split[1]

mismatched_latitude = location_eda.df[~latitude_match]
mismatched_longitude = location_eda.df[~longitude_match]

if not mismatched_latitude.empty or not mismatched_longitude.empty:
    print("Mismatched Latitude rows:")
    print(mismatched_latitude[['Lat Long', 'Latitude']])
    print("\nMismatched Longitude rows:")
    print(mismatched_longitude[['Lat Long', 'Longitude']])
else:
    print("All Latitude and Longitude values are correct.")
# Out:
# All Latitude and Longitude values are correct.

# %%
# Remove column "Lat Long"

location_eda.remove_column('Lat Long')
# Out:
# Column 'Lat Long' removed from the DataFrame.

# %%
# Categorical Features Analysis

location_eda.categorical_analysis(max_categories=10)
# Out:
# /Users/silvanoquarto/Desktop/PROJECTS/Churn-Prediction-Explanation/src/data_viz.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=col, palette=palette, order=value_counts.index, width=0.3)
# /Users/silvanoquarto/Desktop/PROJECTS/Churn-Prediction-Explanation/src/data_viz.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=col, palette=palette, order=value_counts.index, width=0.3)
# /Users/silvanoquarto/Desktop/PROJECTS/Churn-Prediction-Explanation/src/data_viz.py:58: FutureWarning:
#
# ...

# %%
# Visualization of points distribution on a map using geopandas and the Latitude and Longitude columns

location_eda.plot_geopoints("Geo_Map/ne_10m_admin_1_states_provinces.shx")

# %% [markdown]
# ## Population

# %%
population_eda = EDA(path['population'])

population_eda.df.head()
# Out:
#    ID  Zip Code  Population
# 0   1     90001       54492
# 1   2     90002       44586
# 2   3     90003       58198
# 3   4     90004       67852
# 4   5     90005       43019

# %%
# Basic Information

population_eda.basic_info()
# Out:
# Shape of the dataset: (1671, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1671 entries, 0 to 1670
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          1671 non-null   int64
#  1   Zip Code    1671 non-null   int64
#  2   Population  1671 non-null   int64
# dtypes: int64(3)
# memory usage: 39.3 KB
#
# Data types and non-null counts:
#  None
#
# Summary statistics:
#                  ID      Zip Code     Population
# count  1671.000000   1671.000000    1671.000000
# mean    836.000000  93678.992220   20276.384201
# std     482.520466   1817.763591   20689.117300
# min       1.000000  90001.000000      11.000000
# 25%     418.500000  92269.000000    1789.000000
# 50%     836.000000  93664.000000   14239.000000
# 75%    1253.500000  95408.000000   32942.500000
# max    1671.000000  96161.000000  105285.000000

# %%
# Check for duplicate values

population_eda.check_duplicate_values()
# Out:
# Duplicate rows: 0
#
# Nothing to remove :)

# %%
# Check for missing values

population_eda.check_missing_values()
# Out:
# Missing values:
#  ID            0
# Zip Code      0
# Population    0
# dtype: int64

# %%
# Extract and Access ID column if any

population_eda.extract_customer_id()

if population_eda.customer_id is not None:
    print(population_eda.customer_id.head())
# Out:
# Customer ID column '['ID']' extracted and removed from the DataFrame.
#    ID
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5

# %%
# Numerical Features Analysis

population_eda.numerical_analysis()

# %%
# Visualize top cities (using Zip Code with location_eda and population_eda) with highest population level

df_cities = pd.merge(location_eda.df.loc[:,['City','Zip Code']], population_eda.df.loc[:,['Population','Zip Code']], on="Zip Code", how="left")

# Select top by population
df_top = df_cities.nlargest(50, 'Population')

# Plotting
plt.figure(figsize=(14, 8))
sns.barplot(x='Population', y='City', data=df_top, palette='viridis', hue='Population', legend= False)
plt.title('Top Zip Codes by Population')
plt.xlabel('Population')
plt.ylabel('City')
plt.show()

# %% [markdown]
# ## Services

# %%
services_eda = EDA(path['services'])

services_eda.df.head()
# Out:
#       Service ID Customer ID  Count Quarter Referred a Friend  \
# 0  IJKDQVSWH3522  8779-QRDMV      1      Q3                No
# 1  BFKMZJAIE2285  7495-OOKFY      1      Q3               Yes
# 2  EIMVJQBMT7187  1658-BYGOY      1      Q3                No
# 3  EROZQXDUU4979  4598-XLKNJ      1      Q3               Yes
# 4  GEEYSJUHY6991  4846-WHAFZ      1      Q3               Yes
#
#    Number of Referrals  Tenure in Months    Offer Phone Service  \
# 0                    0                 1      NaN            No
# 1                    1                 8  Offer E           Yes
# 2                    0                18  Offer D           Yes
# 3                    1                25  Offer C           Yes
# 4                    1                37  Offer C           Yes
#
#    Avg Monthly Long Distance Charges  ... Unlimited Data        Contract  \
# 0                               0.00  ...             No  Month-to-Month
# ...

# %%
# Categorical Columns

services_eda.categorical_columns
# Out:
# ['Service ID',
#  'Customer ID',
#  'Quarter',
#  'Referred a Friend',
#  'Offer',
#  'Phone Service',
#  'Multiple Lines',
#  'Internet Service',
#  'Internet Type',
#  'Online Security',
#  'Online Backup',
#  'Device Protection Plan',
#  'Premium Tech Support',
#  'Streaming TV',
#  'Streaming Movies',
#  'Streaming Music',
#  'Unlimited Data',
#  'Contract',
#  'Paperless Billing',
#  'Payment Method']

# %%
# Numerical Columns

services_eda.numerical_columns
# Out:
# ['Count',
#  'Number of Referrals',
#  'Tenure in Months',
#  'Avg Monthly Long Distance Charges',
#  'Avg Monthly GB Download',
#  'Monthly Charge',
#  'Total Charges',
#  'Total Refunds',
#  'Total Extra Data Charges',
#  'Total Long Distance Charges',
#  'Total Revenue']

# %%
# Basic Information

services_eda.basic_info()
# Out:
# Shape of the dataset: (7043, 31)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Service ID                         7043 non-null   object
#  1   Customer ID                        7043 non-null   object
#  2   Count                              7043 non-null   int64
#  3   Quarter                            7043 non-null   object
#  4   Referred a Friend                  7043 non-null   object
#  5   Number of Referrals                7043 non-null   int64
#  6   Tenure in Months                   7043 non-null   int64
#  7   Offer                              3166 non-null   object
#  8   Phone Service                      7043 non-null   object
#  9   Avg Monthly Long Distance Charges  7043 non-null   float64
#  10  Multiple Lines                     7043 non-null   object
# ...

# %%
# Check for duplicate values

services_eda.check_duplicate_values()
# Out:
# Duplicate rows: 0
#
# Nothing to remove :)

# %%
# Check for missing values

services_eda.check_missing_values()
# Out:
# Missing values:
#  Service ID                              0
# Customer ID                             0
# Count                                   0
# Quarter                                 0
# Referred a Friend                       0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges       0
# Multiple Lines                          0
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download                 0
# Online Security                         0
# Online Backup                           0
# Device Protection Plan                  0
# Premium Tech Support                    0
# Streaming TV                            0
# Streaming Movies                        0
# Streaming Music                         0
# Unlimited Data                          0
# ...

# %%
# Value counts for missing value features

services_eda.df['Internet Type'].value_counts()
# Out:
# Internet Type
# Fiber Optic    3035
# DSL            1652
# Cable           830
# Name: count, dtype: int64

# %%
# Compare 'Internet Type' with 'Internet Service'

services_eda.plot_missing_comparison('Internet Type', 'Internet Service')

# %%
# Compare 'Internet Type' with 'Avg Monthly GB Download'

services_eda.plot_missing_comparison('Internet Type', 'Avg Monthly GB Download')

# %%
# Compare 'Internet Type' with 'Contract'

services_eda.plot_missing_comparison('Internet Type', 'Contract')

# %%
# Missing values in 'Internet Type' filled with 'No Internet'

services_eda.df.fillna({'Internet Type':'No Internet'}, inplace=True)

services_eda.df['Internet Type'].value_counts()
# Out:
# Internet Type
# Fiber Optic    3035
# DSL            1652
# No Internet    1526
# Cable           830
# Name: count, dtype: int64

# %%
# Value counts for missing value features

services_eda.df['Offer'].value_counts()
# Out:
# Offer
# Offer B    824
# Offer E    805
# Offer D    602
# Offer A    520
# Offer C    415
# Name: count, dtype: int64

# %%
# Compare 'Offer' with other categorical features

for i in range(2, len(services_eda.categorical_columns)):

    if services_eda.categorical_columns[i] == 'Offer':
        continue
    services_eda.plot_missing_comparison('Offer', services_eda.categorical_columns[i])
    input("Press enter to continue")

# %%
# Compare 'Offer' with other numerical features

for i in range(1, len(services_eda.numerical_columns)):
    services_eda.plot_missing_comparison('Offer', services_eda.numerical_columns[i])
    input("Press enter to continue")

# %%
# Missing values in 'Offer' filled with 'No Offer' --> preliminary decision (TBC)

services_eda.df.fillna({'Offer':'No Offer'}, inplace=True)

services_eda.df['Offer'].value_counts()
# Out:
# Offer
# No Offer    3877
# Offer B      824
# Offer E      805
# Offer D      602
# Offer A      520
# Offer C      415
# Name: count, dtype: int64

# %%
# Extract and Access ID column if any

services_eda.extract_customer_id()

if services_eda.customer_id is not None:
    print(services_eda.customer_id.head())
# Out:
# Customer ID column '['Service ID', 'Customer ID']' extracted and removed from the DataFrame.
#       Service ID Customer ID
# 0  IJKDQVSWH3522  8779-QRDMV
# 1  BFKMZJAIE2285  7495-OOKFY
# 2  EIMVJQBMT7187  1658-BYGOY
# 3  EROZQXDUU4979  4598-XLKNJ
# 4  GEEYSJUHY6991  4846-WHAFZ

# %%
# Categorical Features Analysis

services_eda.categorical_analysis()
# Out:
# /Users/silvanoquarto/Desktop/PROJECTS/Churn-Prediction-Explanation/src/data_viz.py:81: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=col, palette=palette, order=value_counts.index, width=0.3)
# /Users/silvanoquarto/Desktop/PROJECTS/Churn-Prediction-Explanation/src/data_viz.py:81: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.df, x=col, palette=palette, order=value_counts.index, width=0.3)
# /Users/silvanoquarto/Desktop/PROJECTS/Churn-Prediction-Explanation/src/data_viz.py:81: FutureWarning:
#
# ...

# %%
# Numerical Features Analysis

services_eda.numerical_analysis()
